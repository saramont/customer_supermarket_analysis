# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %%
df = pd.read_csv('customer_supermarket.csv', sep='\t', index_col=0)

# %%
df.head(10)
# Out:
#   BasketID      BasketDate  Sale  CustomerID CustomerCountry  ProdID  \
# 0   536365  01/12/10 08:26  2,55     17850.0  United Kingdom  85123A
# 1   536365  01/12/10 08:26  3,39     17850.0  United Kingdom   71053
# 2   536365  01/12/10 08:26  2,75     17850.0  United Kingdom  84406B
# 3   536365  01/12/10 08:26  3,39     17850.0  United Kingdom  84029G
# 4   536365  01/12/10 08:26  3,39     17850.0  United Kingdom  84029E
# 5   536365  01/12/10 08:26  7,65     17850.0  United Kingdom   22752
# 6   536365  01/12/10 08:26  4,25     17850.0  United Kingdom   21730
# 7   536366  01/12/10 08:28  1,85     17850.0  United Kingdom   22633
# 8   536366  01/12/10 08:28  1,85     17850.0  United Kingdom   22632
# 9   536368  01/12/10 08:34  4,25     13047.0  United Kingdom   22960
#
#                              ProdDescr  Qta
# 0   WHITE HANGING HEART T-LIGHT HOLDER    6
# 1                  WHITE METAL LANTERN    6
# 2       CREAM CUPID HEARTS COAT HANGER    8
# ...

# %%
df.tail(10)
# Out:
#        BasketID      BasketDate  Sale  CustomerID CustomerCountry ProdID  \
# 541900   581587  09/12/11 12:50  3,75     12680.0          France  22730
# 541901   581587  09/12/11 12:50  1,95     12680.0          France  22367
# 541902   581587  09/12/11 12:50  1,95     12680.0          France  22629
# 541903   581587  09/12/11 12:50  4,15     12680.0          France  23256
# 541904   581587  09/12/11 12:50  0,85     12680.0          France  22613
# 541905   581587  09/12/11 12:50   2,1     12680.0          France  22899
# 541906   581587  09/12/11 12:50  4,15     12680.0          France  23254
# 541907   581587  09/12/11 12:50  4,15     12680.0          France  23255
# 541908   581587  09/12/11 12:50  4,95     12680.0          France  22138
# 541909   581587  09/12/11 12:50    18     12680.0          France   POST
#
#                               ProdDescr  Qta
# 541900       ALARM CLOCK BAKELIKE IVORY    4
# 541901  CHILDRENS APRON SPACEBOY DESIGN    8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 471910 entries, 0 to 541909
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   BasketID         471910 non-null  object
#  1   BasketDate       471910 non-null  object
#  2   Sale             471910 non-null  object
#  3   CustomerID       406830 non-null  float64
#  4   CustomerCountry  471910 non-null  object
#  5   ProdID           471910 non-null  object
#  6   ProdDescr        471157 non-null  object
#  7   Qta              471910 non-null  int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 32.4+ MB

# %% [markdown]
# Something wrong with the indices. Indices from 0 to 541909 but only 471910 entries.

# %%
df.shape
# Out:
# (471910, 8)

# %% [markdown]
# Read again the dataset with implicit indexing and delete the first column (which conteins the wrong indeces)

# %%
df = pd.read_csv('customer_supermarket.csv', sep='\t')
df.head()
# Out:
#    Unnamed: 0 BasketID      BasketDate  Sale  CustomerID CustomerCountry  \
# 0           0   536365  01/12/10 08:26  2,55     17850.0  United Kingdom
# 1           1   536365  01/12/10 08:26  3,39     17850.0  United Kingdom
# 2           2   536365  01/12/10 08:26  2,75     17850.0  United Kingdom
# 3           3   536365  01/12/10 08:26  3,39     17850.0  United Kingdom
# 4           4   536365  01/12/10 08:26  3,39     17850.0  United Kingdom
#
#    ProdID                            ProdDescr  Qta
# 0  85123A   WHITE HANGING HEART T-LIGHT HOLDER    6
# 1   71053                  WHITE METAL LANTERN    6
# 2  84406B       CREAM CUPID HEARTS COAT HANGER    8
# 3  84029G  KNITTED UNION FLAG HOT WATER BOTTLE    6
# 4  84029E       RED WOOLLY HOTTIE WHITE HEART.    6

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df.head()
# Out:
#   BasketID      BasketDate  Sale  CustomerID CustomerCountry  ProdID  \
# 0   536365  01/12/10 08:26  2,55     17850.0  United Kingdom  85123A
# 1   536365  01/12/10 08:26  3,39     17850.0  United Kingdom   71053
# 2   536365  01/12/10 08:26  2,75     17850.0  United Kingdom  84406B
# 3   536365  01/12/10 08:26  3,39     17850.0  United Kingdom  84029G
# 4   536365  01/12/10 08:26  3,39     17850.0  United Kingdom  84029E
#
#                              ProdDescr  Qta
# 0   WHITE HANGING HEART T-LIGHT HOLDER    6
# 1                  WHITE METAL LANTERN    6
# 2       CREAM CUPID HEARTS COAT HANGER    8
# 3  KNITTED UNION FLAG HOT WATER BOTTLE    6
# 4       RED WOOLLY HOTTIE WHITE HEART.    6

# %%
df.tail()
# Out:
#        BasketID      BasketDate  Sale  CustomerID CustomerCountry ProdID  \
# 471905   581587  09/12/11 12:50   2,1     12680.0          France  22899
# 471906   581587  09/12/11 12:50  4,15     12680.0          France  23254
# 471907   581587  09/12/11 12:50  4,15     12680.0          France  23255
# 471908   581587  09/12/11 12:50  4,95     12680.0          France  22138
# 471909   581587  09/12/11 12:50    18     12680.0          France   POST
#
#                               ProdDescr  Qta
# 471905     CHILDREN'S APRON DOLLY GIRL     6
# 471906    CHILDRENS CUTLERY DOLLY GIRL     4
# 471907  CHILDRENS CUTLERY CIRCUS PARADE    4
# 471908    BAKING SET 9 PIECE RETROSPOT     3
# 471909                          POSTAGE    1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471910 entries, 0 to 471909
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   BasketID         471910 non-null  object
#  1   BasketDate       471910 non-null  object
#  2   Sale             471910 non-null  object
#  3   CustomerID       406830 non-null  float64
#  4   CustomerCountry  471910 non-null  object
#  5   ProdID           471910 non-null  object
#  6   ProdDescr        471157 non-null  object
#  7   Qta              471910 non-null  int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 28.8+ MB

# %% [markdown]
# Now entries are indexed well.
#
# Why is Sale of type object?
#
# Why is CustomerID of type float? Maybe because of the null values, np.nan is of type float.

# %%
df_nullCustID = df[df.CustomerID.isnull()]
df_nullCustID
# Out:
#        BasketID      BasketDate     Sale  CustomerID CustomerCountry  ProdID  \
# 1442     536544  01/12/10 14:32     2,51         NaN  United Kingdom   21774
# 1443     536544  01/12/10 14:32     1,66         NaN  United Kingdom   21787
# 1444     536544  01/12/10 14:32     1,66         NaN  United Kingdom   21790
# 1445     536544  01/12/10 14:32     2,51         NaN  United Kingdom   21791
# 1446     536544  01/12/10 14:32     0,43         NaN  United Kingdom   21802
# ...         ...             ...      ...         ...             ...     ...
# 471536   581498  09/12/11 10:26     4,13         NaN  United Kingdom   85038
# 471537   581498  09/12/11 10:26     3,29         NaN  United Kingdom  85049a
# 471538   581498  09/12/11 10:26     4,96         NaN  United Kingdom   85150
# 471539   581498  09/12/11 10:26    10,79         NaN  United Kingdom   85174
# 471540   581498  09/12/11 10:26  1714,17         NaN  United Kingdom     DOT
#
# ...

# %%
df_nullCustID['CustomerCountry'].value_counts()
# Out:
# United Kingdom    64383
# EIRE                339
# Hong Kong           138
# Unspecified          96
# Switzerland          55
# France               33
# Israel               19
# Portugal             15
# Bahrain               2
# Name: CustomerCountry, dtype: int64

# %%
df_nullDesc = df[df.ProdDescr.isnull()]
df_nullDesc[df_nullDesc.CustomerID.isnull()]
# Out:
#        BasketID      BasketDate Sale  CustomerID CustomerCountry  ProdID  \
# 1729     536546  01/12/10 14:33    0         NaN  United Kingdom   22145
# 1765     536550  01/12/10 14:34    0         NaN  United Kingdom   85044
# 1766     536553  01/12/10 14:35    0         NaN  United Kingdom   37461
# 3738     536764  02/12/10 14:42    0         NaN  United Kingdom  84952C
# 3739     536765  02/12/10 14:43    0         NaN  United Kingdom  84952C
# ...         ...             ...  ...         ...             ...     ...
# 455480   580381  02/12/11 17:58    0         NaN  United Kingdom   21758
# 467099   581199  07/12/11 18:26    0         NaN  United Kingdom   84581
# 467102   581203  07/12/11 18:31    0         NaN  United Kingdom   23406
# 467104   581209  07/12/11 18:35    0         NaN  United Kingdom   21620
# 467988   581234  08/12/11 10:33    0         NaN  United Kingdom   72817
#
#        ProdDescr  Qta
# 1729         NaN    1
# 1765         NaN    1
# ...

# %% [markdown]
# All rows that have null prod. description have null customerID too.
# There are also negative quantities.

# %%
df[df['Qta'] < 0]
# Out:
#        BasketID      BasketDate    Sale  CustomerID CustomerCountry  ProdID  \
# 141     C536379  01/12/10 09:41    27,5     14527.0  United Kingdom       D
# 154     C536383  01/12/10 09:49    4,65     15311.0  United Kingdom  35004C
# 235     C536391  01/12/10 10:24    1,65     17548.0  United Kingdom   22556
# 236     C536391  01/12/10 10:24    0,29     17548.0  United Kingdom   21984
# 237     C536391  01/12/10 10:24    0,29     17548.0  United Kingdom   21983
# ...         ...             ...     ...         ...             ...     ...
# 470979  C581490  09/12/11 09:57    0,83     14397.0  United Kingdom   23144
# 471541  C581499  09/12/11 10:28  224,69     15498.0  United Kingdom       M
# 471715  C581568  09/12/11 11:57   10,95     15311.0  United Kingdom   21258
# 471716  C581569  09/12/11 11:58    1,25     17315.0  United Kingdom   84978
# 471717  C581569  09/12/11 11:58    1,25     17315.0  United Kingdom   20979
#
#                                ProdDescr  Qta
# ...

# %%
df_nullDesc['Sale'].value_counts()
# Out:
# 0    753
# Name: Sale, dtype: int64

# %% [markdown]
# All rows that have null prod. description have value 0 in Sale.

# %%
df_nullDesc['CustomerCountry'].value_counts()
# Out:
# United Kingdom    753
# Name: CustomerCountry, dtype: int64

# %% [markdown]
# All rows that have null prod. description have value United Kingdom in CustomerCountry.

# %%
df['BasketID'].value_counts()
# Out:
# 576339     542
# 573585     535
# 579196     533
# 580727     529
# 578270     442
#           ...
# C569387      1
# C566725      1
# C548573      1
# 554534       1
# C579277      1
# Name: BasketID, Length: 24627, dtype: int64

# %% [markdown]
# BasketID should be numbers?

# %%
df['BasketDate'].value_counts()
# Out:
# 14/11/11 15:27    543
# 31/10/11 14:41    535
# 28/11/11 15:54    534
# 05/12/11 17:17    530
# 23/11/11 13:39    444
#                  ...
# 28/06/11 14:47      1
# 02/12/10 11:56      1
# 14/07/11 14:00      1
# 29/11/11 12:38      1
# 18/03/11 12:15      1
# Name: BasketDate, Length: 22428, dtype: int64

# %%
sale = df['Sale'].value_counts()
sale
# Out:
# 1,25       48519
# 1,65       37834
# 2,95       27492
# 0,85       27407
# 0,42       23230
#            ...
# 2,85           1
# 1270,06        1
# 7,6            1
# 13,99          1
# 101,92         1
# Name: Sale, Length: 1146, dtype: int64

# %%
sale['0']
# Out:
# 1279

# %% [markdown]
# 'Sale' attribute has value 0 in 1279 rows.

# %%
sale.index.values.min()
# Out:
# '-11062,06'

# %%
df[df['Sale'] == '-11062,06']
# Out:
#        BasketID      BasketDate       Sale  CustomerID CustomerCountry ProdID  \
# 256523  A563186  12/08/11 14:51  -11062,06         NaN  United Kingdom      B
# 256524  A563187  12/08/11 14:52  -11062,06         NaN  United Kingdom      B
#
#               ProdDescr  Qta
# 256523  Adjust bad debt    1
# 256524  Adjust bad debt    1

# %% [markdown]
# There are negative 'sale' values. But it's ok in this case...

# %%
sale.index.values.max()
# Out:
# '99,96'

# %% [markdown]
# Wrong max, because the type is string I think...
#
# Check again when is converted to float.

# %%
for v in sale.index.values:
    print(v)
# Out:
# 1,25
# 1,65
# 2,95
# 0,85
# 0,42
# 4,95
# 3,75
# 2,1
# 2,08
# 1,95
# 1,45
# 2,55
# 0,83
# 2,46
# 0,39
# 5,95
# 0,65
# 4,13
# 0,55
# 4,25
# 7,95
# 1,63
# 3,29
# 4,15
# 9,95
# 8,5
# 0,29
# 1,69
# 12,75
# 8,25
# 5,79
# 3,95
# 2,89
# 0,79
# 6,75
# 8,29
# 4,96
# 3,25
# 0,19
# 7,46
# 1,06
# 10,79
# 0,95
# 6,25
# 2,49
# 2,51
# 0
# 16,95
# 6,95
# 1,66
# 0,72
# 1,79
# 14,95
# 0,21
# 2,25
# 12,5
# 4,21
# 3,36
# 5,45
# 10,95
# 3,39
# 8,95
# 4,65
# 16,63
# 1,49
# 5,75
# 12,46
# 1,85
# 18
# 5,91
# 7,5
# 0,12
# 0,75
# 7,65
# 0,36
# 6,63
# 8,47
# 6,35
# 0,63
# 15,79
# 24,96
# 5,06
# 7,08
# 7,62
# 0,38
# 0,82
# 3,45
# 9,96
# 2,92
# 1,04
# 3,35
# 0,43
# 14,13
# 15
# 8,15
# 19,96
# 1,28
# 20,79
# 0,59
# 2,75
# 4,58
# 7,9
# 11,02
# 15,95
# 13,29
# 11,63
# 2,9
# 6,65
# 10,4
# 11,95
# 50
# 39,95
# 0,64
# 1,55
# 40
# 1
# 16,98
# 0,06
# 19,95
# 9,13
# 4,98
# 0,62
# 2,5
# 28
# 0,81
# 6,45
# 12,72
# 0,14
# 25,49
# 10,75
# 14,96
# 14,43
# 24,95
# 25
# 5,39
# 3,81
# 6,77
# 0,34
# 3,73
# 125
# 16,65
# 0,04
# ...

# %% [markdown]
# All numbers.
#
# Should be converted to float, but before doing that ',' (commas) must be replaced with '.' (points).

# %%
# something like that...
s = '-12,5'
comma_pos = s.find(',')
if comma_pos >= 0:
    s = s[: comma_pos] + '.' + s[comma_pos+1 :]
print(s)
# Out:
# -12.5

# %%
df['CustomerID'].value_counts()
# Out:
# 17841.0    7983
# 14911.0    5903
# 14096.0    5128
# 12748.0    4642
# 14606.0    2782
#            ...
# 12943.0       1
# 13135.0       1
# 18068.0       1
# 17347.0       1
# 16093.0       1
# Name: CustomerID, Length: 4372, dtype: int64

# %%
df['CustomerCountry'].value_counts()
# Out:
# United Kingdom          426261
# Germany                   9495
# France                    8525
# EIRE                      7824
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               1932
# Portugal                  1495
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Unspecified                340
# USA                        291
# Israel                     269
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Hong Kong                  138
# Malta                      127
# United Arab Emirates        68
# ...

# %% [markdown]
# There is 'Unspecified' as country name.

# %%
df['ProdID'].value_counts()
# Out:
# 85123A    2191
# 22423     2042
# 85099B    1917
# 47566     1569
# 20725     1492
#           ...
# 35832        1
# 85065        1
# 21858        1
# 84971l       1
# 17001        1
# Name: ProdID, Length: 3953, dtype: int64

# %%
df['ProdDescr'].value_counts()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    2212
# REGENCY CAKESTAND 3 TIER              2042
# JUMBO BAG RED RETROSPOT               1917
# PARTY BUNTING                         1569
# LUNCH BAG RED RETROSPOT               1491
#                                       ...
# ROSE PENDANT TRIPLE SHELL NECKLACE       1
# BREAD BIN, DINER STYLE, IVORY            1
# FOUND                                    1
# NEW BAROQUE B'FLY NECKLACE GREEN         1
# BLUE/NAT SHELL NECKLACE W PENDANT        1
# Name: ProdDescr, Length: 4097, dtype: int64

# %%
qta = df['Qta'].value_counts()
qta
# Out:
#  1        109408
#  2         69537
#  12        60508
#  6         39152
#  4         35165
#            ...
#  80995         1
#  374           1
# -1100          1
#  3906          1
#  2700          1
# Name: Qta, Length: 597, dtype: int64

# %% [markdown]
# There are negative quantities.

# %%
df.describe()
# Out:
#           CustomerID            Qta
# count  406830.000000  471910.000000
# mean    15287.684160      10.716533
# std      1713.603074     231.355136
# min     12346.000000  -80995.000000
# 25%     13953.000000       1.000000
# 50%     15152.000000       4.000000
# 75%     16791.000000      12.000000
# max     18287.000000   80995.000000

# %% [markdown]
# 'Sale' is missing from the description because it is an object...why?
#
# As previously noted, there are negative quantities.
#
# Negative quantities could be replaced with their absolute value.

# %%
df[df['Qta'] < 0]
# Out:
#        BasketID      BasketDate    Sale  CustomerID CustomerCountry  ProdID  \
# 141     C536379  01/12/10 09:41    27,5     14527.0  United Kingdom       D
# 154     C536383  01/12/10 09:49    4,65     15311.0  United Kingdom  35004C
# 235     C536391  01/12/10 10:24    1,65     17548.0  United Kingdom   22556
# 236     C536391  01/12/10 10:24    0,29     17548.0  United Kingdom   21984
# 237     C536391  01/12/10 10:24    0,29     17548.0  United Kingdom   21983
# ...         ...             ...     ...         ...             ...     ...
# 470979  C581490  09/12/11 09:57    0,83     14397.0  United Kingdom   23144
# 471541  C581499  09/12/11 10:28  224,69     15498.0  United Kingdom       M
# 471715  C581568  09/12/11 11:57   10,95     15311.0  United Kingdom   21258
# 471716  C581569  09/12/11 11:58    1,25     17315.0  United Kingdom   84978
# 471717  C581569  09/12/11 11:58    1,25     17315.0  United Kingdom   20979
#
#                                ProdDescr  Qta
# ...

# %%
df['Qta'] = df['Qta'].apply(abs)

# %%
df.describe()
# Out:
#           CustomerID            Qta
# count  406830.000000  471910.000000
# mean    15287.684160      12.207512
# std      1713.603074     231.281256
# min     12346.000000       1.000000
# 25%     13953.000000       2.000000
# 50%     15152.000000       4.000000
# 75%     16791.000000      12.000000
# max     18287.000000   80995.000000

# %% [markdown]
# There are no negative 'Qta' values now.

# %%
df[df['Qta'] == 80995]
# Out:
#        BasketID      BasketDate  Sale  CustomerID CustomerCountry ProdID  \
# 470951   581483  09/12/11 09:15  2,08     16446.0  United Kingdom  23843
# 470952  C581484  09/12/11 09:27  2,08     16446.0  United Kingdom  23843
#
#                           ProdDescr    Qta
# 470951  PAPER CRAFT , LITTLE BIRDIE  80995
# 470952  PAPER CRAFT , LITTLE BIRDIE  80995

# %% [markdown]
# Let's convert 'Sale' from type object/string to type float64.

# %%
def convert_to_float(s):
    comma_pos = s.find(',')
    if comma_pos >= 0:
        s = s[: comma_pos] + '.' + s[comma_pos+1 :]
    return float(s)

df['Sale'] = df['Sale'].apply(convert_to_float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471910 entries, 0 to 471909
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   BasketID         471910 non-null  object
#  1   BasketDate       471910 non-null  object
#  2   Sale             471910 non-null  float64
#  3   CustomerID       406830 non-null  float64
#  4   CustomerCountry  471910 non-null  object
#  5   ProdID           471910 non-null  object
#  6   ProdDescr        471157 non-null  object
#  7   Qta              471910 non-null  int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 28.8+ MB

# %%
df.describe()
# Out:
#                 Sale     CustomerID            Qta
# count  471910.000000  406830.000000  471910.000000
# mean        4.030945   15287.684160      12.207512
# std        83.769380    1713.603074     231.281256
# min    -11062.060000   12346.000000       1.000000
# 25%         1.250000   13953.000000       2.000000
# 50%         2.080000   15152.000000       4.000000
# 75%         3.750000   16791.000000      12.000000
# max     38970.000000   18287.000000   80995.000000

# %%
df[df['Sale'] == 38970]
# Out:
#        BasketID      BasketDate     Sale  CustomerID CustomerCountry ProdID  \
# 189987  C556445  10/06/11 15:31  38970.0     15098.0  United Kingdom      M
#
#        ProdDescr  Qta
# 189987    Manual    1

# %%
df[df['Sale'] < 0]
# Out:
#        BasketID      BasketDate      Sale  CustomerID CustomerCountry ProdID  \
# 256523  A563186  12/08/11 14:51 -11062.06         NaN  United Kingdom      B
# 256524  A563187  12/08/11 14:52 -11062.06         NaN  United Kingdom      B
#
#               ProdDescr  Qta
# 256523  Adjust bad debt    1
# 256524  Adjust bad debt    1

# %% [markdown]
# Could drop these rows.

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 471905    False
# 471906    False
# 471907    False
# 471908    False
# 471909    False
# Length: 471910, dtype: bool

# %%
df.duplicated().value_counts()
# Out:
# False    466678
# True       5232
# dtype: int64

# %%
df[df.duplicated(keep=False)].head(20)
# Out:
#     BasketID      BasketDate  Sale  CustomerID CustomerCountry ProdID  \
# 485   536409  01/12/10 11:45  4.95     17908.0  United Kingdom  22111
# 489   536409  01/12/10 11:45  2.10     17908.0  United Kingdom  22866
# 494   536409  01/12/10 11:45  1.25     17908.0  United Kingdom  21866
# 517   536409  01/12/10 11:45  1.25     17908.0  United Kingdom  21866
# 521   536409  01/12/10 11:45  2.95     17908.0  United Kingdom  22900
# 527   536409  01/12/10 11:45  2.10     17908.0  United Kingdom  22866
# 537   536409  01/12/10 11:45  2.95     17908.0  United Kingdom  22900
# 539   536409  01/12/10 11:45  4.95     17908.0  United Kingdom  22111
# 548   536412  01/12/10 11:49  2.95     17920.0  United Kingdom  22327
# 555   536412  01/12/10 11:49  2.95     17920.0  United Kingdom  22327
# 556   536412  01/12/10 11:49  2.95     17920.0  United Kingdom  22273
# 565   536412  01/12/10 11:49  1.65     17920.0  United Kingdom  21448
# ...

# %% [markdown]
# Drop duplicated rows

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().value_counts()
# Out:
# False    466678
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 466678 entries, 0 to 471909
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   BasketID         466678 non-null  object
#  1   BasketDate       466678 non-null  object
#  2   Sale             466678 non-null  float64
#  3   CustomerID       401605 non-null  float64
#  4   CustomerCountry  466678 non-null  object
#  5   ProdID           466678 non-null  object
#  6   ProdDescr        465925 non-null  object
#  7   Qta              466678 non-null  int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.0+ MB

# %%
from dateutil.parser import parse

def is_date(string, fuzzy=False):
    """
    Return whether the string can be interpreted as a date.

    :param string: str, string to check for date
    :param fuzzy: bool, ignore unknown tokens in string if True
    """
    try: 
        parse(string, fuzzy=fuzzy)
        return True

    except ValueError:
        return False


is_date_output = df['BasketDate'].apply(is_date)
is_date_output
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 471905    True
# 471906    True
# 471907    True
# 471908    True
# 471909    True
# Name: BasketDate, Length: 466678, dtype: bool

# %%
is_date_output.value_counts()
# Out:
# True    466678
# Name: BasketDate, dtype: int64

# %% [markdown]
# All date are well formatted.

# %%
import datetime

def validate(date_text):
    try:
        datetime.datetime.strptime(date_text, '%d/%m/%y %H:%M')
        return True
    except ValueError:
        return False

    
correct_date_format = df['BasketDate'].apply(validate)
correct_date_format.value_counts()
# Out:
# True    466678
# Name: BasketDate, dtype: int64

# %% [markdown]
# All dates are in the same format.

# %%
df['BasketDate'] = pd.to_datetime(df['BasketDate'], format="%d/%m/%y %H:%M")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 466678 entries, 0 to 471909
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   BasketID         466678 non-null  object
#  1   BasketDate       466678 non-null  datetime64[ns]
#  2   Sale             466678 non-null  float64
#  3   CustomerID       401605 non-null  float64
#  4   CustomerCountry  466678 non-null  object
#  5   ProdID           466678 non-null  object
#  6   ProdDescr        465925 non-null  object
#  7   Qta              466678 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.0+ MB

# %%
# Check how many BascketID have letters

import re

def search_letters(the_string):
    if re.search('[a-zA-Z]', the_string) is None:
        return False
    return True

letters_output = df['BasketID'].apply(search_letters)
letters_output.value_counts()
# Out:
# False    454594
# True       8602
# Name: BasketID, dtype: int64

# %%
df[df['BasketID'].apply(search_letters)]
# Out:
#        BasketID          BasketDate   Sale  CustomerID CustomerCountry  \
# 154     C536383 2010-12-01 09:49:00   4.65     15311.0  United Kingdom
# 235     C536391 2010-12-01 10:24:00   1.65     17548.0  United Kingdom
# 236     C536391 2010-12-01 10:24:00   0.29     17548.0  United Kingdom
# 237     C536391 2010-12-01 10:24:00   0.29     17548.0  United Kingdom
# 238     C536391 2010-12-01 10:24:00   0.29     17548.0  United Kingdom
# ...         ...                 ...    ...         ...             ...
# 470978  C581490 2011-12-09 09:57:00   1.95     14397.0  United Kingdom
# 470979  C581490 2011-12-09 09:57:00   0.83     14397.0  United Kingdom
# 471715  C581568 2011-12-09 11:57:00  10.95     15311.0  United Kingdom
# 471716  C581569 2011-12-09 11:58:00   1.25     17315.0  United Kingdom
# 471717  C581569 2011-12-09 11:58:00   1.25     17315.0  United Kingdom
#
#         ProdID                          ProdDescr  Qta
# 154     35004C    SET OF 3 COLOURED  FLYING DUCKS    1
# ...

# %% [markdown]
# Chiedere alla prof...

# %%
def check_is_integer(f):
    if np.isnan(f): 
        return True
    else:
        return f.is_integer()

is_integer_output = df['CustomerID'].apply(check_is_integer)
is_integer_output.value_counts()
# Out:
# True    466678
# Name: CustomerID, dtype: int64

# %% [markdown]
# As we can see, CustomerID is either NaN or a whole number.

# %% [markdown]
# We are interested in analysing products bought by customers, therefore we can drop the two rows with negative 'Sale' value since they represent two refunds, and we can drop rows where 'Sale' value equals 0.

# %%
df = df[df['Sale'] > 0]

# %%
years = df['BasketDate'].dt.year
years.value_counts()
# Out:
# 2011    431652
# 2010     33746
# Name: BasketDate, dtype: int64

# %%
years.value_counts(ascending=True).plot(kind='bar', title='Number of purchases per year')

# %%
df['BasketDate'].min()
# Out:
# Timestamp('2010-12-01 08:26:00')

# %% [markdown]
# For the year 2010, the dataset contains only purchases made during december.

# %%
df['BasketDate'].max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %% [markdown]
# The purchases in the dataset range from december 2010 to december 2011.

# %%
months = df['BasketDate'].dt.month
months.value_counts()
# Out:
# 11    73313
# 12    54848
# 10    54615
# 9     44844
# 7     32857
# 5     32439
# 6     31838
# 3     31707
# 8     31085
# 1     28080
# 4     26159
# 2     23613
# Name: BasketDate, dtype: int64

# %%
months.value_counts(sort=False).plot(kind='bar', title='Number of purchases per month')

# %% [markdown]
# But in this graph december has 9 more days considered (all december 2010 plus first 9 days of december 2011).

# %%
df_no_dec_11 = df[df['BasketDate'] < '2011/12/01']
df_no_dec_11['BasketDate'].dt.month.value_counts(sort=False).plot(kind='bar', title='Number of purchases per month')

# %% [markdown]
# Here december is considered has all the other months.

# %%
df_no_dec_11 = df[df['BasketDate'] < '2011/12/01']
df_no_dec_11['BasketDate'].dt.month.value_counts(ascending=True).plot(kind='bar', title='Number of purchases per month (months ordered by number of purchases)')

# %%
df.describe()['Sale']
# Out:
# count    465398.000000
# mean          4.107731
# std          81.173317
# min           0.001000
# 25%           1.250000
# 50%           2.080000
# 75%           3.950000
# max       38970.000000
# Name: Sale, dtype: float64

# %%
df[df['Sale'] > 500]
# Out:
#        BasketID          BasketDate     Sale  CustomerID CustomerCountry  \
# 2463     536592 2010-12-01 17:06:00   607.49         NaN  United Kingdom
# 5194     536876 2010-12-03 11:36:00   887.52         NaN  United Kingdom
# 11780    537434 2010-12-06 16:57:00   950.99         NaN  United Kingdom
# 12532   C537610 2010-12-07 13:23:00   631.31         NaN  United Kingdom
# 13140    537638 2010-12-07 15:28:00   836.14         NaN  United Kingdom
# ...         ...                 ...      ...         ...             ...
# 467457   581217 2011-12-08 09:20:00   863.80         NaN  United Kingdom
# 468158   581238 2011-12-08 10:53:00  1683.75         NaN  United Kingdom
# 470140   581439 2011-12-08 16:30:00   938.59         NaN  United Kingdom
# 471201   581492 2011-12-09 10:03:00   933.17         NaN  United Kingdom
# 471540   581498 2011-12-09 10:26:00  1714.17         NaN  United Kingdom
#
#        ProdID       ProdDescr  Qta
# 2463      DOT  DOTCOM POSTAGE    1
# ...

# %%
df[df['ProdID'] == 'DOT']
# Out:
#        BasketID          BasketDate     Sale  CustomerID CustomerCountry  \
# 2463     536592 2010-12-01 17:06:00   607.49         NaN  United Kingdom
# 4780     536862 2010-12-03 11:13:00   254.43         NaN  United Kingdom
# 5194     536876 2010-12-03 11:36:00   887.52         NaN  United Kingdom
# 11780    537434 2010-12-06 16:57:00   950.99         NaN  United Kingdom
# 13140    537638 2010-12-07 15:28:00   836.14         NaN  United Kingdom
# ...         ...                 ...      ...         ...             ...
# 467457   581217 2011-12-08 09:20:00   863.80         NaN  United Kingdom
# 468158   581238 2011-12-08 10:53:00  1683.75         NaN  United Kingdom
# 470140   581439 2011-12-08 16:30:00   938.59         NaN  United Kingdom
# 471201   581492 2011-12-09 10:03:00   933.17         NaN  United Kingdom
# 471540   581498 2011-12-09 10:26:00  1714.17         NaN  United Kingdom
#
#        ProdID       ProdDescr  Qta
# 2463      DOT  DOTCOM POSTAGE    1
# ...

# %%
df[df['ProdID'] == 'M']
# Out:
#        BasketID          BasketDate    Sale  CustomerID CustomerCountry  \
# 1976     536569 2010-12-01 15:35:00    1.25     16274.0  United Kingdom
# 1987     536569 2010-12-01 15:35:00   18.95     16274.0  United Kingdom
# 5713     536981 2010-12-03 14:26:00    0.85     14723.0  United Kingdom
# 6796     537077 2010-12-05 11:59:00    0.42     17062.0  United Kingdom
# 7350     537137 2010-12-05 12:43:00    0.85     16327.0  United Kingdom
# ...         ...                 ...     ...         ...             ...
# 463683   580956 2011-12-06 14:23:00    1.25     17841.0  United Kingdom
# 464983  C581009 2011-12-07 09:15:00  125.00     16971.0  United Kingdom
# 466090  C581145 2011-12-07 13:48:00    9.95     17490.0  United Kingdom
# 469195   581405 2011-12-08 13:50:00    0.42     13521.0  United Kingdom
# 471541  C581499 2011-12-09 10:28:00  224.69     15498.0  United Kingdom
#
#        ProdID ProdDescr  Qta
# 1976        M    Manual    1
# 1987        M    Manual    1
# ...

# %%
df[df['ProdID'].apply(str.isalpha)]
# Out:
#        BasketID          BasketDate    Sale  CustomerID CustomerCountry  \
# 45       536370 2010-12-01 08:45:00   18.00     12583.0          France
# 141     C536379 2010-12-01 09:41:00   27.50     14527.0  United Kingdom
# 386      536403 2010-12-01 11:27:00   15.00     12791.0     Netherlands
# 1122     536527 2010-12-01 13:04:00   18.00     12662.0         Germany
# 1976     536569 2010-12-01 15:35:00    1.25     16274.0  United Kingdom
# ...         ...                 ...     ...         ...             ...
# 471541  C581499 2011-12-09 10:28:00  224.69     15498.0  United Kingdom
# 471730   581570 2011-12-09 11:59:00   18.00     12662.0         Germany
# 471767   581574 2011-12-09 12:09:00   18.00     12526.0         Germany
# 471768   581578 2011-12-09 12:16:00   18.00     12713.0         Germany
# 471909   581587 2011-12-09 12:50:00   18.00     12680.0          France
#
#        ProdID ProdDescr  Qta
# 45       POST   POSTAGE    3
# 141         D  Discount    1
# ...

# %%
df[df['ProdID'].apply(str.isalpha)]['ProdID'].value_counts()
# Out:
# POST         1221
# M             495
# DOT           336
# D              77
# S              26
# AMAZONFEE      17
# CRUK           16
# DCGSSBOY        6
# DCGSSGIRL       4
# PADS            3
# m               1
# Name: ProdID, dtype: int64

# %%
def is_not_alpha(s):
    return not s.isalpha()

df = df[df['ProdID'].apply(is_not_alpha)]
df
# Out:
#        BasketID          BasketDate  Sale  CustomerID CustomerCountry  ProdID  \
# 0        536365 2010-12-01 08:26:00  2.55     17850.0  United Kingdom  85123A
# 1        536365 2010-12-01 08:26:00  3.39     17850.0  United Kingdom   71053
# 2        536365 2010-12-01 08:26:00  2.75     17850.0  United Kingdom  84406B
# 3        536365 2010-12-01 08:26:00  3.39     17850.0  United Kingdom  84029G
# 4        536365 2010-12-01 08:26:00  3.39     17850.0  United Kingdom  84029E
# ...         ...                 ...   ...         ...             ...     ...
# 471904   581587 2011-12-09 12:50:00  0.85     12680.0          France   22613
# 471905   581587 2011-12-09 12:50:00  2.10     12680.0          France   22899
# 471906   581587 2011-12-09 12:50:00  4.15     12680.0          France   23254
# 471907   581587 2011-12-09 12:50:00  4.15     12680.0          France   23255
# 471908   581587 2011-12-09 12:50:00  4.95     12680.0          France   22138
#
# ...

# %%
def search_letters(the_string):
    if re.search('[a-z]', the_string) is None:
        return False
    return True

strange_desc = df['ProdDescr'].apply(search_letters)
df[df['ProdDescr'].apply(search_letters)]['ProdDescr'].value_counts()
# Out:
# BAG 125g SWIRLY MARBLES                281
# 3 TRADITIONAl BISCUIT CUTTERS  SET     221
# BAG 250g SWIRLY MARBLES                221
# POLYESTER FILLER PAD 40x40cm           187
# POLYESTER FILLER PAD 45x45cm           138
# BAG 500g SWIRLY MARBLES                138
# FRENCH BLUE METAL DOOR SIGN No         121
# Next Day Carriage                       80
# POLYESTER FILLER PAD 45x30cm            37
# POLYESTER FILLER PAD 30CMx30CM          26
# Bank Charges                            25
# ESSENTIAL BALM 3.5g TIN IN ENVELOPE     24
# NUMBER TILE COTTAGE GARDEN No           21
# NUMBER TILE VINTAGE FONT No             18
# FOLK ART GREETING CARD,pack/12          10
# THE KING GIFT BAG 25x24x12cm             8
# POLYESTER FILLER PAD 65CMx65CM           6
# Dotcomgiftshop Gift Voucher £30.00       4
# Dotcomgiftshop Gift Voucher £40.00       3
# Dotcomgiftshop Gift Voucher £10.00       3
# FLOWERS HANDBAG blue and orange          3
# Dotcomgiftshop Gift Voucher £20.00       3
# ...
